# %% [markdown]
# <a href="https://colab.research.google.com/github/aleksandra-bozic/covid_19_Analysis_and_Visualization_using_Plotly_Express/blob/main/Covid_19_analysis_and_Visualization_Using_Plotly_Express.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# <ipython-input-12-4fb9b05de165> in <cell line: 3>()
#       1 s3Bucket = boto3.resource('s3')
#       2 obj = s3Bucket.Object(s3_bucket, s3_key)
# ----> 3 data = obj.get()['Body'].read().decode('utf-8')
#       4 with tempfile.NamedTemporaryFile(mode='w', delete=False) as file:
#       5     file.write(data)
#
# /usr/local/lib/python3.10/dist-packages/boto3/resources/factory.py in do_action(self, *args, **kwargs)
#     579             # instance via ``self``.
#     580             def do_action(self, *args, **kwargs):
# --> 581                 response = action(self, *args, **kwargs)
#     582
#     583                 if hasattr(self, 'load'):
#
# /usr/local/lib/python3.10/dist-packages/boto3/resources/action.py in __call__(self, parent, *args, **kwargs)
#      86         )
#      87
# ...
